# %%
import numpy as np
import pandas as pd


# Load data file
train_input = pd.read_csv('train_new.csv', delimiter=',')

# %%
train_input
# Out:
#       match  samerace  age_o  dec_o  field_cd  like_o  shar_o  sinc_o  race_o  \
# 0         0         0     27      0         1     7.0     6.0     8.0       2
# 1         0         0     22      0         1     8.0     5.0     8.0       2
# 2         1         1     22      1         1    10.0    10.0    10.0       4
# 3         1         0     23      1         1     7.0     8.0     8.0       2
# 4         1         0     24      1         1     8.0     7.0     7.0       3
# ...     ...       ...    ...    ...       ...     ...     ...     ...     ...
# 8143      0         0     26      1        18     6.0     5.0     5.0       3
# 8144      0         0     24      0        18     2.0     2.0     3.0       6
# 8145      0         0     29      0        18     2.0     1.0     1.0       3
# 8146      0         0     22      1        18     6.0     6.0     7.0       4
# 8147      0         0     22      1        18     8.0     7.0     8.0       4
#
# ...

# %%
# Take out career_c and income for comparison

data = np.genfromtxt('train_new.csv', delimiter=',')
career = data[:, 18:19]
income = data[:, 19:20]

# %%
career
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [ 7.],
#        [ 7.],
#        [ 7.]])

# %%
income

# %%
import math

data_new = None
count = 0
for i in range(len(np.asarray(career))):
    if math.isnan(np.asarray(income[i])) or math.isnan(np.asarray(income[i])):
        count+=1
print('Dataset length:', len(data)-1, 'missing values:', count)
# Out:
# Dataset length: 8148 missing values: 4644

# %%
# Take out the career_c and income whose column is na for regression
import pandas as pd

df = pd.read_csv('train_new.csv', delimiter=',')
# train_reg = df[pd.notnull(df[['match','samerace', 'age_o', 'dec_o', 'field_cd', 'like_o', 'shar_o', 'sinc_o', 'race_o', 'intel_o', 'attr_o', 'amb_o', 'fun_o', 'age', 'race', 'imprace', 'imprelig', 'exphappy', 'career_c', 'income', 'dec']])]
# train_reg = df[['career_c', 'income']]
train_reg = df.drop(df[df.gender > 0].index)
# train_reg = train_reg.dropna()
train_reg.to_csv('female.csv')

# %%
# Take out the career_c and income whose column is na for regression
import pandas as pd

df = pd.read_csv('train_new.csv', delimiter=',')
# train_reg = df[pd.notnull(df[['match','samerace', 'age_o', 'dec_o', 'field_cd', 'like_o', 'shar_o', 'sinc_o', 'race_o', 'intel_o', 'attr_o', 'amb_o', 'fun_o', 'age', 'race', 'imprace', 'imprelig', 'exphappy', 'career_c', 'income', 'dec']])]
# train_reg = df[['career_c', 'income']]
train_reg = df.drop(df[df.gender < 1].index)
# train_reg = train_reg.dropna()
train_reg.to_csv('male.csv')

# %%
len(train_reg)
# Out:
# 4074

# %%
df = pd.read_csv('male.csv', delimiter=',')
male = df.dropna(subset=['income'])
male.to_csv('male_new.csv')

# %%
len(male)
# Out:
# 1730

# %%
df = pd.read_csv('female.csv', delimiter=',')
female = df.dropna(subset=['income'])
female.to_csv('female_new.csv')

# %%
len(female)
# Out:
# 1775

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
import numpy as np

np.random.seed(10)


# read and divide data into test and train sets
admit_data = np.genfromtxt('train_reg.csv', delimiter=',')
X_data, Y_data = admit_data[1:, 1:2], admit_data[1:, -1]
Y_data = Y_data.reshape(Y_data.shape[0], 1)

idx = np.arange(X_data.shape[0])
np.random.shuffle(idx)
X_data, Y_data = X_data[idx], Y_data[idx]

X_data = (X_data - np.mean(X_data, axis=0)) / np.std(X_data, axis=0)

split = 0.7
# create train set
trainX = X_data[:int(X_data.shape[0] * split)]
trainY = Y_data[:int(Y_data.shape[0] * split)]

# create test set
testX = X_data[:int(X_data.shape[0] * split * -1)]
testY = Y_data[:int(Y_data.shape[0] * split * -1)]

# randomly choose 50 samples from test set
rand = np.random.choice(testX.shape[0], 50, replace=True)
testX = testX[rand]
testY = testY[rand]


# define the keras model
model = Sequential()
model.add(Dense(4, input_dim=1, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam')

model.fit(trainX, trainY, epochs=2000, verbose=1)

# make a prediction
predictions = model.predict(testX)

# summarize the first 10 cases
for i in range(10):
    print('%s predict: %d (expected %d)' % (testX[i].tolist(), predictions[i], testY[i]))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# Regression training input
train_input = np.genfromtxt('train_reg.csv', delimiter=',')
X_data, Y_data = train_input[1:, 1:2], train_input[1:, -1]
Y_data = Y_data.reshape(Y_data.shape[0], 1)
idx = np.arange(X_data.shape[0])
np.random.shuffle(idx)
X_data, Y_data = X_data[idx], Y_data[idx]
X_data = (X_data- np.mean(X_data, axis=0))/ np.std(X_data, axis=0)

trainX, testX, trainY, testY = train_test_split(trainX, trainY, test_size=0.3, shuffle=True)

regr = linear_model.LinearRegression()
regr.fit(trainX, trainY)
predict_income = regr.predict(testX)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(testY, predict_income))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(testY, predict_income))

# Plot outputs
plt.scatter(testX, testY,  color='black')
plt.plot(testX, predict_income, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
len(df)
