# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
import numpy as np
from sklearn 

np.random.seed(10)
filling_values = -1

# scale data
def scale(X, X_min, X_max):
    return (X - X_min) / (X_max - X_min)

# load the dataset
dataset = np.genfromtxt('train_new.csv', delimiter=',', filling_values=filling_values)

# split into input (X) and output (y) variables
X = dataset[1:, :19]
y_ = dataset[1:, -1].astype(int)
X = scale(X, np.min(X, axis=0), np.max(X, axis=0))

y = np.zeros((y_.shape[0], 2))
y[np.arange(y_.shape[0]), y_ - 1] = 1  # one hot matrix

# define the keras model
model = Sequential()
model.add(Dense(10, input_dim=19, activation='relu'))
model.add(Dense(2, activation='softmax'))

# compile the keras model
sgd = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=32, validation_split=0.3, verbose=1, shuffle=1)

# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))

# make class predictions with the model
predictions = model.predict_classes(X)

# summarize the first 10 cases

y.astype(int)
y_ = y[:, 1]

for i in range(10):
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y_[i]))
# Out:
# Train on 3992 samples, validate on 1711 samples
# Epoch 1/150
# 3992/3992 [==============================] - 0s 67us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 2/150
# 3992/3992 [==============================] - 0s 28us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 3/150
# 3992/3992 [==============================] - 0s 27us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 4/150
# 3992/3992 [==============================] - 0s 25us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 5/150
# 3992/3992 [==============================] - 0s 27us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 6/150
# 3992/3992 [==============================] - 0s 27us/step - loss: 8.9073 - accuracy: 0.4191 - val_loss: 9.2304 - val_accuracy: 0.3980
# Epoch 7/150
# ...
