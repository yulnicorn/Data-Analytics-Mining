# %%
# Import relavant libraries
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Import csv files

# %%
df = pd.read_csv('train_new.csv')
df2 = df.copy()

# %% [markdown]
# # Splitting gender into male and female

# %%
df = df.drop(df[df.gender > 0].index)
df2 = df.drop(df[df.gender < 1].index)

# %%
df.to_csv('female.csv')
df2.to_csv('male.csv')

# %% [markdown]
# # Dropping rows with empty values

# %%
df = pd.read_csv('female.csv')
df = df.dropna()
df.to_csv('female(non_impute).csv')

df2 = pd.read_csv('male.csv')
df2 = df2.dropna()
df2.to_csv('male(non_impute).csv')

# %% [markdown]
# # Imputing colums with missing values

# %%
df = pd.read_csv('female.csv')
fill_NaN = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_DF = pd.DataFrame(fill_NaN.fit_transform(df))
imputed_DF.columns = df.columns
imputed_DF.index = df.index
imputed_DF.to_csv('female(imputed).csv')


df2 = pd.read_csv('male.csv')
fill_NaN = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_DF2 = pd.DataFrame(fill_NaN.fit_transform(df2))
imputed_DF2.columns = df2.columns
imputed_DF2.index = df2.index
imputed_DF2.to_csv('male(imputed).csv')

# %%
import pandas as pd
df = pd.read_csv('male(imputed).csv')
df.describe()

# %%
df.dtypes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(data=df)

# %% [markdown]
# # Impute rows with missing values

# %%
import pandas as pd

df_cleaning = pd.read_csv('Speed Dating Data(v2).csv')
df_cleaning.columns
# Out:
# Index(['iid', 'gender', 'idg', 'condtn', 'wave', 'round', 'position', 'order',
#        'pid', 'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att',
#        'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o', 'prob_o',
#        'met_o', 'age', 'field_cd', 'race', 'imprace', 'imprelig', 'goal',
#        'date', 'go_out', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
#        'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
#        'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
#        'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',
#        'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1',
#        'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1', 'dec', 'attr',
#        'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met'],
#       dtype='object')

# %%
df_cleaning = df_cleaning[['gender', 'samerace', 'age_o', 'race_o', 'pf_o_att',
       'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'attr_o',
       'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o', 'prob_o',
       'met_o', 'age', 'field_cd', 'race', 'imprace', 'imprelig',]]

# %%
df_cleaning

# %%
df = pd.read_csv('speed_data(latest).csv')
df
# Out:
#       gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# 0          0         0     27       2      35.0      20.0      20.0      20.0
# 1          0         0     22       2      60.0       0.0       0.0      40.0
# 2          0         1     22       4      19.0      18.0      19.0      18.0
# 3          0         0     23       2      30.0       5.0      15.0      40.0
# 4          0         0     24       3      30.0      10.0      20.0      10.0
# ...      ...       ...    ...     ...       ...       ...       ...       ...
# 8143       1         0     26       3      10.0      10.0      30.0      20.0
# 8144       1         0     24       6      50.0      20.0      10.0       5.0
# 8145       1         0     29       3      40.0      10.0      30.0      10.0
# 8146       1         0     22       4      10.0      25.0      25.0      10.0
# 8147       1         0     22       4      20.0      20.0      10.0      15.0
#
# ...

# %%
df = df.dropna(subset=['career_c'])

# %%
df
# Out:
#       gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# 30         0         1     27       2      35.0      20.0      20.0      20.0
# 31         0         1     22       2      60.0       0.0       0.0      40.0
# 32         0         0     22       4      19.0      18.0      19.0      18.0
# 33         0         1     23       2      30.0       5.0      15.0      40.0
# 34         0         0     24       3      30.0      10.0      20.0      10.0
# ...      ...       ...    ...     ...       ...       ...       ...       ...
# 8143       1         0     26       3      10.0      10.0      30.0      20.0
# 8144       1         0     24       6      50.0      20.0      10.0       5.0
# 8145       1         0     29       3      40.0      10.0      30.0      10.0
# 8146       1         0     22       4      10.0      25.0      25.0      10.0
# 8147       1         0     22       4      20.0      20.0      10.0      15.0
#
# ...

# %%
df.to_csv('speed_data(career_cleaned).csv')

# %%
df = pd.read_csv('speed_data(career_cleaned).csv')
df
# Out:
#       Unnamed: 0  gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  \
# 0             30       0         1     27       2      35.0      20.0
# 1             31       0         1     22       2      60.0       0.0
# 2             32       0         0     22       4      19.0      18.0
# 3             33       0         1     23       2      30.0       5.0
# 4             34       0         0     24       3      30.0      10.0
# ...          ...     ...       ...    ...     ...       ...       ...
# 8005        8143       1         0     26       3      10.0      10.0
# 8006        8144       1         0     24       6      50.0      20.0
# 8007        8145       1         0     29       3      40.0      10.0
# 8008        8146       1         0     22       4      10.0      25.0
# 8009        8147       1         0     22       4      20.0      20.0
#
#       pf_o_int  pf_o_fun  pf_o_amb  ...  prob_o  met_o  age  field_cd  race  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'samerace', 'age_o', 'race_o', 'pf_o_att',
#        'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o', 'prob_o',
#        'met_o', 'age', 'field_cd', 'race', 'imprace', 'imprelig', 'income',
#        'career_c', 'dec_o'],
#       dtype='object')

# %%
# df_toImpute = df[['career_c', 'income']]
# df_toImpute

df_income = df[['income']]
df_income['income'].replace(to_replace=",", value=r"", regex=True, inplace=True)
df_income['income'] = df_income['income'].astype(float)
df_income
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:6788: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        income
# 0     37754.0
# 1     37754.0
# 2     37754.0
# 3     37754.0
# 4     37754.0
# ...       ...
# 8005      NaN
# 8006      NaN
# 8007      NaN
# 8008      NaN
# 8009      NaN
#
# [8010 rows x 1 columns]

# %%
df_toImpute = df[['career_c']]

newdf = pd.DataFrame()
newdf['career_c'] = df_toImpute['career_c']
newdf['income'] = df_income['income']
print(newdf)
# Out:
#       career_c   income
# 0          1.0  37754.0
# 1          1.0  37754.0
# 2          1.0  37754.0
# 3          1.0  37754.0
# 4          1.0  37754.0
# ...        ...      ...
# 8005       7.0      NaN
# 8006       7.0      NaN
# 8007       7.0      NaN
# 8008       7.0      NaN
# 8009       7.0      NaN
#
# [8010 rows x 2 columns]

# %%
import impyute.imputation.cs.em as em

newdf = newdf.values
newdf = em(newdf)

# %%
imputed = pd.DataFrame(newdf)

# %%
imputed.columns=['career_c', 'income']

# %%
imputed
# Out:
#       career_c        income
# 0          1.0  37754.000000
# 1          1.0  37754.000000
# 2          1.0  37754.000000
# 3          1.0  37754.000000
# 4          1.0  37754.000000
# ...        ...           ...
# 8005       7.0  27976.861637
# 8006       7.0  13553.694738
# 8007       7.0  53435.404152
# 8008       7.0  23581.708133
# 8009       7.0  62117.884187
#
# [8010 rows x 2 columns]

# %%
df2 = df.iloc[:, 0:24]
df2
df3 = df.iloc[:, -1]
df3
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8005    1
# 8006    0
# 8007    0
# 8008    1
# 8009    1
# Name: dec_o, Length: 8010, dtype: int64

# %%
result = pd.concat([df2,imputed,df3],axis=1)
result.isnull().sum()
# Out:
# Unnamed: 0       0
# gender           0
# samerace         0
# age_o            0
# race_o           0
# pf_o_att         0
# pf_o_sin         0
# pf_o_int         0
# pf_o_fun         9
# pf_o_amb         9
# pf_o_sha        31
# attr_o         172
# sinc_o         243
# intel_o        263
# fun_o          315
# amb_o          673
# shar_o        1018
# like_o         209
# prob_o         273
# met_o            0
# age              0
# field_cd         0
# race             0
# imprace          0
# career_c         0
# income           0
# dec_o            0
# dtype: int64

# %%
result
# Out:
#       Unnamed: 0  gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  \
# 0             30       0         1     27       2      35.0      20.0
# 1             31       0         1     22       2      60.0       0.0
# 2             32       0         0     22       4      19.0      18.0
# 3             33       0         1     23       2      30.0       5.0
# 4             34       0         0     24       3      30.0      10.0
# ...          ...     ...       ...    ...     ...       ...       ...
# 8005        8143       1         0     26       3      10.0      10.0
# 8006        8144       1         0     24       6      50.0      20.0
# 8007        8145       1         0     29       3      40.0      10.0
# 8008        8146       1         0     22       4      10.0      25.0
# 8009        8147       1         0     22       4      20.0      20.0
#
#       pf_o_int  pf_o_fun  pf_o_amb  ...  like_o  prob_o  met_o  age  field_cd  \
# ...

# %%
attrShar= result[['shar_o', 'pf_o_sha']]
attrAmb = result[['amb_o', 'pf_o_amb', 'fun_o', 'intel_o', 'pf_o_int', 'pf_o_sha', 'pf_o_sin']]
attrFun = result[['pf_o_sha', 'fun_o']]
attrSinc = result[['pf_o_sha', 'fun_o', 'amb_o', 'sinc_o']]
attrInt = result[['pf_o_sha', 'sinc_o', 'intel_o']]

# %%
import missingno as m
import matplotlib.pyplot as plt

m.matrix(attrAmb, labels=True)

# %%
attrShar = em(attrShar)
attrAmb = em(attrAmb)
attrFun = em(attrFun)
attrSinc = em(attrSinc)
attrInt = em(attrInt)
# Out:
# /usr/local/lib/python3.7/site-packages/impyute/util/preprocess.py:52: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   args[0] = args[0].as_matrix()

# %%
attrShar.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
attrShar.columns=['shar_o', 'pf_o_sha']                  
attrAmb.columns=['amb_o', 'pf_o_amb', 'fun_o', 'intel_o', 'pf_o_int', 'pf_o_sha', 'pf_o_sin']
attrFun.columns=['pf_o_sha', 'fun_o']
attrSinc.columns=['pf_o_sha', 'fun_o', 'amb_o', 'sinc_o']
attrInt.columns=['pf_o_sha', 'sinc_o', 'intel_o']

# %%
attrShar
# Out:
#       shar_o  pf_o_sha
# 0        5.0   5.00000
# 1        5.0   0.00000
# 2       10.0  12.00000
# 3        9.0   5.00000
# 4        9.0  20.00000
# ...      ...       ...
# 8005     5.0  15.00000
# 8006     2.0   5.00000
# 8007     1.0  20.49065
# 8008     6.0  20.00000
# 8009     7.0  30.00000
#
# [8010 rows x 2 columns]

# %%
df4 = result.iloc[:, 1:12]
df4
# Out:
#       gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# 0          0         1     27       2      35.0      20.0      20.0      20.0
# 1          0         1     22       2      60.0       0.0       0.0      40.0
# 2          0         0     22       4      19.0      18.0      19.0      18.0
# 3          0         1     23       2      30.0       5.0      15.0      40.0
# 4          0         0     24       3      30.0      10.0      20.0      10.0
# ...      ...       ...    ...     ...       ...       ...       ...       ...
# 8005       1         0     26       3      10.0      10.0      30.0      20.0
# 8006       1         0     24       6      50.0      20.0      10.0       5.0
# 8007       1         0     29       3      40.0      10.0      30.0      10.0
# 8008       1         0     22       4      10.0      25.0      25.0      10.0
# 8009       1         0     22       4      20.0      20.0      10.0      15.0
#
#       pf_o_amb  pf_o_sha  attr_o
# ...

# %%
df5 = result.iloc[:, 17:26]
df5
# Out:
#       like_o  prob_o  met_o  age  field_cd  race  imprace  career_c  \
# 0        6.0     3.0      1   23         1     2        1       1.0
# 1        6.0     3.0      0   23         1     2        1       1.0
# 2       10.0    10.0      0   23         1     2        1       1.0
# 3        8.0    10.0      0   23         1     2        1       1.0
# 4        9.0     7.0      1   23         1     2        1       1.0
# ...      ...     ...    ...  ...       ...   ...      ...       ...
# 8005     6.0     1.0      0   25        18     2        1       7.0
# 8006     2.0     2.0      1   25        18     2        1       7.0
# 8007     2.0     1.0      1   25        18     2        1       7.0
# 8008     6.0     4.0      1   25        18     2        1       7.0
# 8009     8.0     5.0      1   25        18     2        1       7.0
#
#             income
# 0     37754.000000
# 1     37754.000000
# 2     37754.000000
# 3     37754.000000
# 4     37754.000000
# ...            ...
# ...

# %%
df6 = result.iloc[:, -1]
df6
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8005    1
# 8006    0
# 8007    0
# 8008    1
# 8009    1
# Name: dec_o, Length: 8010, dtype: int64

# %%
result = pd.concat([df4, attrShar[["shar_o"]], attrAmb[["amb_o"]], attrFun[["fun_o"]], attrInt[["intel_o"]], df5, df6],axis=1)
result.isnull().sum()
# Out:
# gender        0
# samerace      0
# age_o         0
# race_o        0
# pf_o_att      0
# pf_o_sin      0
# pf_o_int      0
# pf_o_fun      9
# pf_o_amb      9
# pf_o_sha     31
# attr_o      172
# shar_o        0
# amb_o         0
# fun_o         0
# intel_o       0
# like_o      209
# prob_o      273
# met_o         0
# age           0
# field_cd      0
# race          0
# imprace       0
# career_c      0
# income        0
# dec_o         0
# dtype: int64

# %%
sum(n < 0 for n in result[['income']].values.flatten())
# Out:
# 37

# %%
result = result.drop(result[result.income < 0].index)
result
# Out:
#       gender  samerace  age_o  race_o  pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  \
# 0          0         1     27       2      35.0      20.0      20.0      20.0
# 1          0         1     22       2      60.0       0.0       0.0      40.0
# 2          0         0     22       4      19.0      18.0      19.0      18.0
# 3          0         1     23       2      30.0       5.0      15.0      40.0
# 4          0         0     24       3      30.0      10.0      20.0      10.0
# ...      ...       ...    ...     ...       ...       ...       ...       ...
# 8005       1         0     26       3      10.0      10.0      30.0      20.0
# 8006       1         0     24       6      50.0      20.0      10.0       5.0
# 8007       1         0     29       3      40.0      10.0      30.0      10.0
# 8008       1         0     22       4      10.0      25.0      25.0      10.0
# 8009       1         0     22       4      20.0      20.0      10.0      15.0
#
# ...

# %%
sum(n < 0 for n in result[['income']].values.flatten())
# Out:
# 0

# %%
result.isnull().sum()
# Out:
# gender        0
# samerace      0
# age_o         0
# race_o        0
# pf_o_att      0
# pf_o_sin      0
# pf_o_int      0
# pf_o_fun      9
# pf_o_amb      9
# pf_o_sha     30
# attr_o      170
# shar_o        0
# amb_o         0
# fun_o         0
# intel_o       0
# like_o      208
# prob_o      271
# met_o         0
# age           0
# field_cd      0
# race          0
# imprace       0
# career_c      0
# income        0
# dec_o         0
# dtype: int64

# %%
result = result.dropna(subset=['pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'attr_o', 'like_o', 'prob_o'])

# %%
result.columns
# Out:
# Index(['gender', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
#        'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'attr_o', 'shar_o',
#        'amb_o', 'fun_o', 'intel_o', 'like_o', 'prob_o', 'met_o', 'age',
#        'field_cd', 'race', 'imprace', 'career_c', 'income', 'dec_o'],
#       dtype='object')

# %%
result.isnull().sum()
# Out:
# gender      0
# samerace    0
# age_o       0
# race_o      0
# pf_o_att    0
# pf_o_sin    0
# pf_o_int    0
# pf_o_fun    0
# pf_o_amb    0
# pf_o_sha    0
# attr_o      0
# shar_o      0
# amb_o       0
# fun_o       0
# intel_o     0
# like_o      0
# prob_o      0
# met_o       0
# age         0
# field_cd    0
# race        0
# imprace     0
# career_c    0
# income      0
# dec_o       0
# dtype: int64

# %%
result.to_csv('speed_data_final.csv')

# %%
df = pd.read_csv('speed_data_final.csv')

df1 = df.drop(df[df.gender > 0].index)
df2 = df.drop(df[df.gender < 1].index)

df1.to_csv('female(final).csv')
df2.to_csv('male(final).csv')

# %%
df = pd.read_csv('female(final).csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  gender  samerace  age_o  race_o  pf_o_att  \
# 0              0             0       0         1     27       2      35.0
# 1              1             1       0         1     22       2      60.0
# 2              2             2       0         0     22       4      19.0
# 3              3             3       0         1     23       2      30.0
# 4              4             4       0         0     24       3      30.0
# ...          ...           ...     ...       ...    ...     ...       ...
# 3807        7232          7543       0         0     30       2      40.0
# 3808        7233          7544       0         0     28       2      20.0
# 3809        7234          7545       0         0     30       2      30.0
# 3810        7235          7546       0         0     27       1      40.0
# 3811        7236          7547       0         0     25       2      70.0
#
#       pf_o_sin  pf_o_int  pf_o_fun  ...  like_o  prob_o  met_o  age  field_cd  \
# ...
