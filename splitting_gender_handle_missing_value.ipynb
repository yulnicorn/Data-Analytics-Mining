# %%
# Import relavant libraries
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Import csv files

# %%
df = pd.read_csv('train_new.csv')
df2 = df.copy()

# %% [markdown]
# # Splitting gender into male and female

# %%
df = df.drop(df[df.gender > 0].index)
df2 = df.drop(df[df.gender < 1].index)

# %%
df.to_csv('female.csv')
df2.to_csv('male.csv')

# %% [markdown]
# # Dropping rows with empty values

# %%
df = pd.read_csv('female.csv')
df = df.dropna()
df.to_csv('female(non_impute).csv')

df2 = pd.read_csv('male.csv')
df2 = df2.dropna()
df2.to_csv('male(non_impute).csv')

# %% [markdown]
# # Imputing colums with missing values

# %%
df = pd.read_csv('female.csv')
fill_NaN = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_DF = pd.DataFrame(fill_NaN.fit_transform(df))
imputed_DF.columns = df.columns
imputed_DF.index = df.index
imputed_DF.to_csv('female(imputed).csv')


df2 = pd.read_csv('male.csv')
fill_NaN = SimpleImputer(missing_values=np.nan, strategy='mean')
imputed_DF2 = pd.DataFrame(fill_NaN.fit_transform(df2))
imputed_DF2.columns = df2.columns
imputed_DF2.index = df2.index
imputed_DF2.to_csv('male(imputed).csv')

# %%
import pandas as pd
df = pd.read_csv('male(imputed).csv')
df.describe()
# Out:
#        gender        match     samerace        age_o     field_cd  \
# count  4074.0  4074.000000  4074.000000  4074.000000  4074.000000
# mean      1.0     0.164703     0.400098    26.103584     7.355670
# std       0.0     0.370958     0.489978     3.673860     3.597188
# min       1.0     0.000000     0.000000    19.000000     0.000000
# 25%       1.0     0.000000     0.000000    23.000000     5.000000
# 50%       1.0     0.000000     0.000000    26.000000     8.000000
# 75%       1.0     0.000000     1.000000    28.000000    10.000000
# max       1.0     1.000000     1.000000    55.000000    18.000000
#
#             like_o       shar_o       sinc_o       race_o      intel_o  \
# count  4074.000000  4074.000000  4074.000000  4074.000000  4074.000000
# mean      5.993421     5.410450     7.095984     2.789151     7.442259
# std       1.876027     2.051993     1.834787     1.229784     1.581186
# min       0.000000     0.000000     0.000000     1.000000     0.000000
# 25%       5.000000     4.000000     6.000000     2.000000     7.000000
# 50%       6.000000     5.410450     7.000000     2.000000     8.000000
# 75%       7.000000     7.000000     8.000000     4.000000     8.000000
# max      10.000000    10.000000    10.000000     6.000000    10.000000
#
#             attr_o        amb_o        fun_o          age         race  \
# count  4074.000000  4074.000000  4074.000000  4074.000000  4074.000000
# mean      5.914325     6.950644     6.279641    26.631811     2.734904
# std       1.983110     1.765599     2.012887     3.425748     1.235145
# min       0.000000     0.000000     0.000000    18.000000     1.000000
# 25%       5.000000     6.000000     5.000000    24.000000     2.000000
# 50%       6.000000     7.000000     6.279641    27.000000     2.000000
# 75%       7.000000     8.000000     8.000000    29.000000     4.000000
# max      10.000000    10.000000    10.000000    42.000000     6.000000
#
#            imprace     imprelig     exphappy     career_c        dec_o
# count  4074.000000  4074.000000  4074.000000  4074.000000  4074.000000
# mean      3.461954     3.106038     5.889789     4.892213     0.366961
# std       2.627108     2.570976     1.634359     3.170768     0.482035
# min       1.000000     1.000000     1.000000     1.000000     0.000000
# 25%       1.000000     1.000000     5.000000     2.000000     0.000000
# 50%       3.000000     2.000000     6.000000     5.000000     0.000000
# 75%       6.000000     5.000000     7.000000     7.000000     1.000000
# max      10.000000    10.000000    10.000000    15.000000     1.000000

# %%
df.dtypes
# Out:
# gender        int64
# match         int64
# samerace      int64
# age_o         int64
# field_cd      int64
# like_o      float64
# shar_o      float64
# sinc_o      float64
# race_o        int64
# intel_o     float64
# attr_o      float64
# amb_o       float64
# fun_o       float64
# age           int64
# race          int64
# imprace       int64
# imprelig      int64
# exphappy      int64
# career_c    float64
# dec_o         int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(data=df)
